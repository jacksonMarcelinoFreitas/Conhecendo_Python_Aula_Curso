# %%
#Exercicio: Sorteie 20 numeros entre 10 e 30, inclua os elementos
#pares em uma lista de pares e impares para impares

"""
import random as rd
listaPar = []
listaImpar = []
quant = 20
inferior = 10
superior =30

for i in range (0, quant): # faz o alcance 
    aleatorio = rd.randint(inferior, superior) # faz o intervalo
    if(aleatorio %2 == 0):
        listaPar.append(aleatorio)
    else(aleatorio %2 ==1):
        listaImpar.append(aleatorio)
    print(aleatorio) # exibe os númeors aleátórios
print(listaPar)
print(listaImpar)
"""


import random as rd
par = []
impar = []
sorteados = []
for i in range(20):
    sorteio = rd.randint(10,30)
    sorteados.append(sorteio)
    if sorteio %2 == 0:
        par.append(sorteio)
    else:
        impar.append(sorteio)
print("Valores sorteados: \n")
print(sorteados)
print("Valores pares: \n")
print(par)
print("Valores impares: \n")
print(impar)
# Out:
# Valores sorteados:
#
# [13, 11, 13, 28, 27, 20, 16, 13, 19, 11, 16, 15, 15, 20, 22, 16, 11, 17, 22, 16]
# Valores pares:
#
# [28, 20, 16, 16, 20, 22, 16, 22, 16]
# Valores impares:
#
# [13, 11, 13, 27, 13, 19, 11, 15, 15, 11, 17]
